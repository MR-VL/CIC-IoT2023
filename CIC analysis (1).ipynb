# %%
import pandas as pd

# %%
#Standard Deviation Per Column

import os
import pandas as pd

# Path to the folder containing the CSV files
folder_path = os.path.join(os.getcwd(), 'CIC')

# List of all CSV files in the folder
csv_files = [f for f in os.listdir(folder_path) if f.endswith('.csv')]

num_chunks = {}  # Keep count of the number of rows per column processed
partial_sum = {}  # Sum of values for each column
partial_sum_squares = {}  # Sum of squared values for each column

for csv_file in csv_files:
    csv_path = os.path.join(folder_path, csv_file)
    chunksize = 10000  # Number of rows per chunk
    
    for chunk in pd.read_csv(csv_path, chunksize=chunksize):
        # Iterate through each column in the chunk
        for col in chunk.columns:
            # Skip non-numeric columns
            if not pd.api.types.is_numeric_dtype(chunk[col]):
                continue
            
            # Initialize counters for new columns
            if col not in partial_sum:
                partial_sum[col] = 0
                partial_sum_squares[col] = 0
                num_chunks[col] = 0
            
            # Aggregate partial sums and count
            partial_sum[col] += chunk[col].sum()
            partial_sum_squares[col] += (chunk[col]**2).sum()
            num_chunks[col] += len(chunk[col].dropna())

# Calculate the standard deviation incrementally for each column
stdevs = {}
for col in partial_sum:
    if num_chunks[col] > 1:  # Avoid division by zero
        mean = partial_sum[col] / num_chunks[col]
        variance = (partial_sum_squares[col] / num_chunks[col]) - (mean**2)
        stdevs[col] = variance**0.5  # Standard deviation = sqrt(variance)

# Print the standard deviation for each numeric column
print("Standard Deviation Per Column")
for col, stdev in stdevs.items():
    print(f'{col}: {stdev}')
# Out:
# Standard Deviation Per Column
# flow_duration: 285.03416828033625
# Header_Length: 461331.74232421746
# Protocol Type: 8.945532822145422
# Duration: 14.019187951426009
# Rate: 99562.48957037824
# Srate: 99562.48957037824
# Drate: 0.007250765859210306
# fin_flag_number: 0.28120695314897837
# syn_flag_number: 0.4053977831154013
# rst_flag_number: 0.2869035027063886
# psh_flag_number: 0.28293106060457146
# ack_flag_number: 0.3289320633770767
# ece_flag_number: 0.0012157049878482081
# cwr_flag_number: 0.0008533815996231708
# ack_count: 0.2864314373830108
# syn_count: 0.6635353923256602
# fin_count: 0.32711641412377823
# urg_count: 71.8524528598533
# rst_count: 325.3846543835321
# HTTP: 0.21426078827176917
# HTTPS: 0.22817382472631212
# DNS: 0.01143078636106617
# Telnet: 0.00014635378864648267
# SMTP: 0.00025349219238624606
# SSH: 0.006397722947079261
# IRC: 0.00038721570330887744
# TCP: 0.49451845315212895
# UDP: 0.4086667606492646
# DHCP: 0.0013090269731860019
# ARP: 0.008135211368447137
# ICMP: 0.3700227254461768
# IPv: 0.010614844924732221
# LLC: 0.010614844924732221
# Tot sum: 2613.3026974498607
# Min: 139.69532424955523
# Max: 524.0308959166041
# AVG: 240.9914823770959
# Std: 160.33572024742435
# Tot size: 241.54933889352648
# IAT: 17047351.552197192
# Number: 0.8191531728521831
# Magnitue: 8.628578858997866
# Radius: 226.76964462134535
# Covariance: 323710.676650163
# Variance: 0.23300099600439367
# Weight: 21.06830711089412

# %%
#Logic good but no label mappings

import os
import pandas as pd

# Path to the folder containing the CSV files
folder_path = os.path.join(os.getcwd(), 'CIC')

# List of all CSV files in the folder
csv_files = [f for f in os.listdir(folder_path) if f.endswith('.csv')]

# Dictionaries to store intermediate summaries
num_chunks = {}  # Keep count of the number of rows for each column processed
partial_sum = {}  # Sum of values for each column
partial_sum_squares = {}  # Sum of squared values for each column
max_values = {}  # Maximum values for each column
min_values = {}  # Minimum values for each column
value_counts = {}  # Value counts for mode calculation

chunksize = 1000000000  # Number of rows per chunk

# Process each CSV file in the folder
for csv_file in csv_files:
    csv_path = os.path.join(folder_path, csv_file)
    print(f'Processing file: {csv_file}')

    # Process the file in chunks
    for chunk in pd.read_csv(csv_path, chunksize=chunksize):
        for col in chunk.columns:
            # Check for numeric columns
            if not pd.api.types.is_numeric_dtype(chunk[col]):
                continue

            # Initialize dictionaries for new columns
            if col not in partial_sum:
                partial_sum[col] = 0
                partial_sum_squares[col] = 0
                num_chunks[col] = 0
                max_values[col] = float('-inf')
                min_values[col] = float('inf')
                value_counts[col] = pd.Series(dtype=int)

            # Aggregate statistics
            partial_sum[col] += chunk[col].sum()
            partial_sum_squares[col] += (chunk[col] ** 2).sum()
            num_chunks[col] += len(chunk[col].dropna())
            max_values[col] = max(max_values[col], chunk[col].max())
            min_values[col] = min(min_values[col], chunk[col].min())
            value_counts[col] = value_counts[col].add(chunk[col].value_counts(), fill_value=0)

# Calculate the statistics incrementally for each column
stats_summary = {}

for col in partial_sum:
    if num_chunks[col] > 0:
        mean = partial_sum[col] / num_chunks[col]
        if num_chunks[col] > 1:
            variance = (partial_sum_squares[col] / num_chunks[col]) - (mean ** 2)
            stdev = variance ** 0.5
        else:
            stdev = None

        mode_values = value_counts[col][value_counts[col] == value_counts[col].max()].index.tolist()
        mode = mode_values[0] if mode_values else None

        stats_summary[col] = {
            'Mean': mean,
            'Mode': mode,
            'Max': max_values[col],
            'Min': min_values[col],
            'Standard Deviation': stdev,
        }

# Print the summary statistics for numeric columns
print("\nSummary Statistics Per Column")
for col, stats in stats_summary.items():
    print(f'\n{col}:')
    for stat_name, value in stats.items():
        print(f'  {stat_name}: {value}')
# Out:
# Processing file: part-00000-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00001-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00002-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00003-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00004-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00005-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00006-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00007-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00008-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00009-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00010-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00011-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00012-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00013-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00014-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00015-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00016-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00017-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00018-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00019-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00020-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00021-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00022-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00023-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00024-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00025-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00026-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00027-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00028-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00029-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00030-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00031-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00032-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00033-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00034-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00035-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00036-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00037-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00038-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00039-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00040-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00041-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00042-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00043-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00044-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00045-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00046-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00047-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00048-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00049-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00050-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00051-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00052-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00053-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00054-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00055-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00056-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00057-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00058-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00059-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00060-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00061-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00062-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00063-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00064-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00065-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00066-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00067-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00068-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00069-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00070-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00071-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00072-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00073-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00074-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00075-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00076-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00077-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00078-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00079-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00080-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00081-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00082-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00083-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00084-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00085-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00086-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00087-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00088-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00089-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00090-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00091-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00092-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00093-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00094-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00095-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00096-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00097-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00098-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00099-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00100-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00101-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00102-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00103-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00104-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00105-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00106-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00107-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00108-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00109-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00110-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00111-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00112-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00113-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00114-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00115-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00116-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00117-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00118-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00119-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00120-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00121-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00122-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00123-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00124-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00125-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00126-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00127-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00128-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00129-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00130-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00131-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00132-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00133-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00134-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00135-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00136-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00137-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00138-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00139-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00140-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00141-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00142-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00143-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00144-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00145-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00146-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00147-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00148-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00149-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00150-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00151-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00152-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00153-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00154-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00155-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00156-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00157-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00158-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00159-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00160-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00161-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00162-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00163-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00164-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00165-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00166-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00167-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00168-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
#
# Summary Statistics Per Column
#
# flow_duration:
#   Mean: 5.765449391891019
#   Mode: 0.0
#   Max: 394357.20737375977
#   Min: 0.0
#   Standard Deviation: 285.0341682803361
#
# Header_Length:
#   Mean: 76705.96372046642
#   Mode: 54.0
#   Max: 9907147.75
#   Min: 0.0
#   Standard Deviation: 461331.74232421763
#
# Protocol Type:
#   Mean: 9.065689893437773
#   Mode: 6.0
#   Max: 47.0
#   Min: 0.0
#   Standard Deviation: 8.945532822145418
#
# Duration:
#   Mean: 66.35071687254133
#   Mode: 64.0
#   Max: 255.0
#   Min: 0.0
#   Standard Deviation: 14.019187951425424
#
# Rate:
#   Mean: 9064.057239842243
#   Mode: 0.0
#   Max: 8388608.0
#   Min: 0.0
#   Standard Deviation: 99562.48957037818
#
# Srate:
#   Mean: 9064.057239842243
#   Mode: 0.0
#   Max: 8388608.0
#   Min: 0.0
#   Standard Deviation: 99562.48957037818
#
# Drate:
#   Mean: 5.463949309321336e-06
#   Mode: 0.0
#   Max: 29.71522493800921
#   Min: 0.0
#   Standard Deviation: 0.007250765859210295
#
# fin_flag_number:
#   Mean: 0.08657207459985448
#   Mode: 0.0
#   Max: 1.0
#   Min: 0.0
#   Standard Deviation: 0.28120695314897837
#
# syn_flag_number:
#   Mean: 0.20733528151634328
#   Mode: 0.0
#   Max: 1.0
#   Min: 0.0
#   Standard Deviation: 0.4053977831154013
#
# rst_flag_number:
#   Mean: 0.09050472513738905
#   Mode: 0.0
#   Max: 1.0
#   Min: 0.0
#   Standard Deviation: 0.2869035027063886
#
# psh_flag_number:
#   Mean: 0.08775005767717528
#   Mode: 0.0
#   Max: 1.0
#   Min: 0.0
#   Standard Deviation: 0.28293106060457146
#
# ack_flag_number:
#   Mean: 0.12343168258269684
#   Mode: 0.0
#   Max: 1.0
#   Min: 0.0
#   Standard Deviation: 0.3289320633770767
#
# ece_flag_number:
#   Mean: 1.4779408017880256e-06
#   Mode: 0.0
#   Max: 1.0
#   Min: 0.0
#   Standard Deviation: 0.0012157049878482081
#
# cwr_flag_number:
#   Mean: 7.282606849390272e-07
#   Mode: 0.0
#   Max: 1.0
#   Min: 0.0
#   Standard Deviation: 0.0008533815996231708
#
# ack_count:
#   Mean: 0.09054282818385843
#   Mode: 0.0
#   Max: 7.7
#   Min: 0.0
#   Standard Deviation: 0.2864314373830106
#
# syn_count:
#   Mean: 0.3303578524966207
#   Mode: 0.0
#   Max: 12.87
#   Min: 0.0
#   Standard Deviation: 0.6635353923256606
#
# fin_count:
#   Mean: 0.09907672451840115
#   Mode: 0.0
#   Max: 248.32
#   Min: 0.0
#   Standard Deviation: 0.3271164141237784
#
# urg_count:
#   Mean: 6.2398235560157875
#   Mode: 0.0
#   Max: 4401.7
#   Min: 0.0
#   Standard Deviation: 71.8524528598533
#
# rst_count:
#   Mean: 38.468121319652525
#   Mode: 0.0
#   Max: 9613.0
#   Min: 0.0
#   Standard Deviation: 325.3846543835319
#
# HTTP:
#   Mean: 0.048234225943177375
#   Mode: 0.0
#   Max: 1.0
#   Min: 0.0
#   Standard Deviation: 0.21426078827176917
#
# HTTPS:
#   Mean: 0.05509921812861893
#   Mode: 0.0
#   Max: 1.0
#   Min: 0.0
#   Standard Deviation: 0.22817382472631212
#
# DNS:
#   Mean: 0.00013067995408273542
#   Mode: 0.0
#   Max: 1.0
#   Min: 0.0
#   Standard Deviation: 0.01143078636106617
#
# Telnet:
#   Mean: 2.1419431909971386e-08
#   Mode: 0.0
#   Max: 1.0
#   Min: 0.0
#   Standard Deviation: 0.00014635378864648267
#
# SMTP:
#   Mean: 6.425829572991416e-08
#   Mode: 0.0
#   Max: 1.0
#   Min: 0.0
#   Standard Deviation: 0.00025349219238624606
#
# SSH:
#   Mean: 4.093253437995532e-05
#   Mode: 0.0
#   Max: 1.0
#   Min: 0.0
#   Standard Deviation: 0.006397722947079261
#
# IRC:
#   Mean: 1.499360233697997e-07
#   Mode: 0.0
#   Max: 1.0
#   Min: 0.0
#   Standard Deviation: 0.00038721570330887744
#
# TCP:
#   Mean: 0.5738342704441891
#   Mode: 1.0
#   Max: 1.0
#   Min: 0.0
#   Standard Deviation: 0.49451845315212895
#
# UDP:
#   Mean: 0.21191758342370728
#   Mode: 0.0
#   Max: 1.0
#   Min: 0.0
#   Standard Deviation: 0.4086667606492646
#
# DHCP:
#   Mean: 1.713554552797711e-06
#   Mode: 0.0
#   Max: 1.0
#   Min: 0.0
#   Standard Deviation: 0.0013090269731860019
#
# ARP:
#   Mean: 6.618604460181158e-05
#   Mode: 0.0
#   Max: 1.0
#   Min: 0.0
#   Standard Deviation: 0.008135211368447137
#
# ICMP:
#   Mean: 0.1637215697470573
#   Mode: 0.0
#   Max: 1.0
#   Min: 0.0
#   Standard Deviation: 0.3700227254461768
#
# IPv:
#   Mean: 0.9998873123687216
#   Mode: 1.0
#   Max: 1.0
#   Min: 0.0
#   Standard Deviation: 0.010614844924732221
#
# LLC:
#   Mean: 0.9998873123687216
#   Mode: 1.0
#   Max: 1.0
#   Min: 0.0
#   Standard Deviation: 0.010614844924732221
#
# Tot sum:
#   Mean: 1308.3225728693212
#   Mode: 567.0
#   Max: 127335.8
#   Min: 42.0
#   Standard Deviation: 2613.3026974498616
#
# Min:
#   Mean: 91.60734562244528
#   Mode: 54.0
#   Max: 13583.0
#   Min: 42.0
#   Standard Deviation: 139.69532424955528
#
# Max:
#   Mean: 181.96341779707967
#   Mode: 54.0
#   Max: 49014.0
#   Min: 42.0
#   Standard Deviation: 524.0308959166033
#
# AVG:
#   Mean: 124.66881523774914
#   Mode: 54.0
#   Max: 13583.0
#   Min: 42.0
#   Standard Deviation: 240.99148237709576
#
# Std:
#   Mean: 33.324806486727496
#   Mode: 0.0
#   Max: 12385.2391048564
#   Min: 0.0
#   Standard Deviation: 160.33572024742423
#
# Tot size:
#   Mean: 124.6915673484638
#   Mode: 54.0
#   Max: 13583.0
#   Min: 42.0
#   Standard Deviation: 241.54933889352685
#
# IAT:
#   Mean: 83182525.86645673
#   Mode: 3.0994415283203125e-06
#   Max: 167639436.0415293
#   Min: 0.0
#   Standard Deviation: 17047351.552197162
#
# Number:
#   Mean: 9.498489328199122
#   Mode: 9.5
#   Max: 15.0
#   Min: 1.0
#   Standard Deviation: 0.8191531728518795
#
# Magnitue:
#   Mean: 13.121819976447151
#   Mode: 10.392304845413264
#   Max: 164.8211151521552
#   Min: 9.165151389911676
#   Standard Deviation: 8.628578858997836
#
# Radius:
#   Mean: 47.094984802986566
#   Mode: 0.0
#   Max: 17551.27080917445
#   Min: 0.0
#   Standard Deviation: 226.7696446213456
#
# Covariance:
#   Mean: 30724.356527404383
#   Mode: 0.0
#   Max: 154902159.24774638
#   Min: 0.0
#   Standard Deviation: 323710.6766501625
#
# Variance:
#   Mean: 0.0964375989783293
#   Mode: 0.0
#   Max: 1.0
#   Min: 0.0
#   Standard Deviation: 0.23300099600439414
#
# Weight:
#   Mean: 141.5123696036146
#   Mode: 141.55
#   Max: 244.6
#   Min: 1.0
#   Standard Deviation: 21.068307110893688

# %%
#This one converts the labels from categorical to numerical and also performs the summary statistics on it.

import os
import pandas as pd

# Path to the folder containing the CSV files
folder_path = os.path.join(os.getcwd(), 'CIC')

# List of all CSV files in the folder
csv_files = [f for f in os.listdir(folder_path) if f.endswith('.csv')]

# Dictionaries to store intermediate summaries
num_chunks = {}              # Tracks the number of non-null rows processed per column
partial_sum = {}             # Accumulates the sum of values per column
partial_sum_squares = {}     # Accumulates the sum of squares of values per column (for variance)
max_values = {}              # Tracks the maximum value encountered per column
min_values = {}              # Tracks the minimum value encountered per column
value_counts = {}            # Stores frequency counts of unique values per column
label_mapping = {}           # Maps categorical labels to numerical values

#how many rows will be loaded at one time -> 500k seems to run okay with 16Gigs ram without maxing
# lower number will be slower, this seems like a good balance at least on my machine
chunksize = 500000

# Process each CSV file in the folder
for csv_file in csv_files:
    # Get the full path of the current CSV file
    csv_path = os.path.join(folder_path, csv_file)
    # Display progress by printing the current file being processed
    print(f'Processing file: {csv_file}')

    # Read the CSV file in chunks to avoid memory overload
    for chunk in pd.read_csv(csv_path, chunksize=chunksize):
        # Convert categorical labels to numerical
        if 'label' in chunk.columns:
            # Create label mapping if it doesnt exist
            if not label_mapping:
                unique_labels = chunk['label'].unique()
                label_mapping = {label: idx for idx, label in enumerate(unique_labels)}
            #Map categorical labels to numerical    
            chunk['label'] = chunk['label'].map(label_mapping)

        # Iterate through each column in the chunk
        for col in chunk.columns:
            # Skip non-numeric columns
            if not pd.api.types.is_numeric_dtype(chunk[col]):
                continue

            #initialize
            if col not in partial_sum:
                partial_sum[col] = 0
                partial_sum_squares[col] = 0
                num_chunks[col] = 0
                max_values[col] = float('-inf')
                min_values[col] = float('inf')
                value_counts[col] = pd.Series(dtype=int)

            # Accumulate sum and sum of squares for mean and variance calculations
            partial_sum[col] += chunk[col].sum()
            partial_sum_squares[col] += (chunk[col] ** 2).sum()
            # Update the number of non-null values processed
            num_chunks[col] += len(chunk[col].dropna())
            # Update max and min values
            max_values[col] = max(max_values[col], chunk[col].max())
            min_values[col] = min(min_values[col], chunk[col].min())
            # Update for mode calculation
            value_counts[col] = value_counts[col].add(chunk[col].value_counts(), fill_value=0)

# Calculate the statistics incrementally for each column
stats_summary = {}
print("\nCalculating statistics now")

for col in partial_sum:
    if num_chunks[col] > 0:
        # Calculate values
        mean = partial_sum[col] / num_chunks[col]
        variance = (partial_sum_squares[col] / num_chunks[col]) - (mean ** 2) if num_chunks[col] > 1 else 0
        stdev = variance ** 0.5
        mode_values = value_counts[col][value_counts[col] == value_counts[col].max()].index.tolist()
        mode = mode_values[0] if mode_values else None

        # Store calculated statistics for the current column
        stats_summary[col] = {
            'Mean': mean,
            'Mode': mode,
            'Max': max_values[col],
            'Min': min_values[col],
            'Standard Deviation': stdev,
        }

# Print the summary statistics for numeric columns
print('\nSummary Statistics Per Column')
for col, stats in stats_summary.items():
    print(f'\n{col}:')
    for stat_name, value in stats.items():
        print(f'  {stat_name}: {value}')

# Print the label mapping
print('\nLabel Mapping:')
for label, num in label_mapping.items():
    print(f'  {label} -> {num}')
# Out:
# Processing file: part-00000-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00001-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00002-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00003-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00004-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00005-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00006-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00007-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00008-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00009-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00010-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00011-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00012-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00013-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00014-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00015-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00016-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00017-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00018-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00019-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00020-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00021-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00022-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00023-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00024-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00025-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00026-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00027-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00028-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00029-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00030-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00031-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00032-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00033-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00034-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00035-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00036-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00037-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00038-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00039-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00040-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00041-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00042-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00043-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00044-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00045-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00046-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00047-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00048-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00049-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00050-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00051-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00052-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00053-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00054-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00055-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00056-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00057-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00058-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00059-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00060-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00061-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00062-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00063-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00064-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00065-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00066-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00067-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00068-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00069-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00070-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00071-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00072-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00073-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00074-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00075-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00076-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00077-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00078-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00079-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00080-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00081-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00082-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00083-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00084-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00085-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00086-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00087-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00088-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00089-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00090-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00091-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00092-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00093-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00094-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00095-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00096-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00097-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00098-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00099-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00100-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00101-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00102-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00103-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00104-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00105-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00106-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00107-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00108-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00109-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00110-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00111-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00112-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00113-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00114-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00115-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00116-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00117-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00118-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00119-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00120-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00121-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00122-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00123-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00124-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00125-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00126-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00127-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00128-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00129-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00130-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00131-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00132-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00133-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00134-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00135-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00136-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00137-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00138-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00139-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00140-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00141-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00142-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00143-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00144-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00145-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00146-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00147-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00148-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00149-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00150-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00151-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00152-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00153-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00154-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00155-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00156-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00157-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00158-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00159-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00160-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00161-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00162-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00163-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00164-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00165-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00166-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00167-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00168-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
#
# Calculating statistics now
#
# Summary Statistics Per Column
#
# flow_duration:
#   Mean: 5.765449391891019
#   Mode: 0.0
#   Max: 394357.20737375977
#   Min: 0.0
#   Standard Deviation: 285.0341682803361
#
# Header_Length:
#   Mean: 76705.96372046642
#   Mode: 54.0
#   Max: 9907147.75
#   Min: 0.0
#   Standard Deviation: 461331.74232421763
#
# Protocol Type:
#   Mean: 9.065689893437773
#   Mode: 6.0
#   Max: 47.0
#   Min: 0.0
#   Standard Deviation: 8.945532822145418
#
# Duration:
#   Mean: 66.35071687254133
#   Mode: 64.0
#   Max: 255.0
#   Min: 0.0
#   Standard Deviation: 14.019187951425424
#
# Rate:
#   Mean: 9064.057239842243
#   Mode: 0.0
#   Max: 8388608.0
#   Min: 0.0
#   Standard Deviation: 99562.48957037818
#
# Srate:
#   Mean: 9064.057239842243
#   Mode: 0.0
#   Max: 8388608.0
#   Min: 0.0
#   Standard Deviation: 99562.48957037818
#
# Drate:
#   Mean: 5.463949309321336e-06
#   Mode: 0.0
#   Max: 29.71522493800921
#   Min: 0.0
#   Standard Deviation: 0.007250765859210295
#
# fin_flag_number:
#   Mean: 0.08657207459985448
#   Mode: 0.0
#   Max: 1.0
#   Min: 0.0
#   Standard Deviation: 0.28120695314897837
#
# syn_flag_number:
#   Mean: 0.20733528151634328
#   Mode: 0.0
#   Max: 1.0
#   Min: 0.0
#   Standard Deviation: 0.4053977831154013
#
# rst_flag_number:
#   Mean: 0.09050472513738905
#   Mode: 0.0
#   Max: 1.0
#   Min: 0.0
#   Standard Deviation: 0.2869035027063886
#
# psh_flag_number:
#   Mean: 0.08775005767717528
#   Mode: 0.0
#   Max: 1.0
#   Min: 0.0
#   Standard Deviation: 0.28293106060457146
#
# ack_flag_number:
#   Mean: 0.12343168258269684
#   Mode: 0.0
#   Max: 1.0
#   Min: 0.0
#   Standard Deviation: 0.3289320633770767
#
# ece_flag_number:
#   Mean: 1.4779408017880256e-06
#   Mode: 0.0
#   Max: 1.0
#   Min: 0.0
#   Standard Deviation: 0.0012157049878482081
#
# cwr_flag_number:
#   Mean: 7.282606849390272e-07
#   Mode: 0.0
#   Max: 1.0
#   Min: 0.0
#   Standard Deviation: 0.0008533815996231708
#
# ack_count:
#   Mean: 0.09054282818385843
#   Mode: 0.0
#   Max: 7.7
#   Min: 0.0
#   Standard Deviation: 0.2864314373830106
#
# syn_count:
#   Mean: 0.3303578524966207
#   Mode: 0.0
#   Max: 12.87
#   Min: 0.0
#   Standard Deviation: 0.6635353923256606
#
# fin_count:
#   Mean: 0.09907672451840115
#   Mode: 0.0
#   Max: 248.32
#   Min: 0.0
#   Standard Deviation: 0.3271164141237784
#
# urg_count:
#   Mean: 6.2398235560157875
#   Mode: 0.0
#   Max: 4401.7
#   Min: 0.0
#   Standard Deviation: 71.8524528598533
#
# rst_count:
#   Mean: 38.468121319652525
#   Mode: 0.0
#   Max: 9613.0
#   Min: 0.0
#   Standard Deviation: 325.3846543835319
#
# HTTP:
#   Mean: 0.048234225943177375
#   Mode: 0.0
#   Max: 1.0
#   Min: 0.0
#   Standard Deviation: 0.21426078827176917
#
# HTTPS:
#   Mean: 0.05509921812861893
#   Mode: 0.0
#   Max: 1.0
#   Min: 0.0
#   Standard Deviation: 0.22817382472631212
#
# DNS:
#   Mean: 0.00013067995408273542
#   Mode: 0.0
#   Max: 1.0
#   Min: 0.0
#   Standard Deviation: 0.01143078636106617
#
# Telnet:
#   Mean: 2.1419431909971386e-08
#   Mode: 0.0
#   Max: 1.0
#   Min: 0.0
#   Standard Deviation: 0.00014635378864648267
#
# SMTP:
#   Mean: 6.425829572991416e-08
#   Mode: 0.0
#   Max: 1.0
#   Min: 0.0
#   Standard Deviation: 0.00025349219238624606
#
# SSH:
#   Mean: 4.093253437995532e-05
#   Mode: 0.0
#   Max: 1.0
#   Min: 0.0
#   Standard Deviation: 0.006397722947079261
#
# IRC:
#   Mean: 1.499360233697997e-07
#   Mode: 0.0
#   Max: 1.0
#   Min: 0.0
#   Standard Deviation: 0.00038721570330887744
#
# TCP:
#   Mean: 0.5738342704441891
#   Mode: 1.0
#   Max: 1.0
#   Min: 0.0
#   Standard Deviation: 0.49451845315212895
#
# UDP:
#   Mean: 0.21191758342370728
#   Mode: 0.0
#   Max: 1.0
#   Min: 0.0
#   Standard Deviation: 0.4086667606492646
#
# DHCP:
#   Mean: 1.713554552797711e-06
#   Mode: 0.0
#   Max: 1.0
#   Min: 0.0
#   Standard Deviation: 0.0013090269731860019
#
# ARP:
#   Mean: 6.618604460181158e-05
#   Mode: 0.0
#   Max: 1.0
#   Min: 0.0
#   Standard Deviation: 0.008135211368447137
#
# ICMP:
#   Mean: 0.1637215697470573
#   Mode: 0.0
#   Max: 1.0
#   Min: 0.0
#   Standard Deviation: 0.3700227254461768
#
# IPv:
#   Mean: 0.9998873123687216
#   Mode: 1.0
#   Max: 1.0
#   Min: 0.0
#   Standard Deviation: 0.010614844924732221
#
# LLC:
#   Mean: 0.9998873123687216
#   Mode: 1.0
#   Max: 1.0
#   Min: 0.0
#   Standard Deviation: 0.010614844924732221
#
# Tot sum:
#   Mean: 1308.3225728693212
#   Mode: 567.0
#   Max: 127335.8
#   Min: 42.0
#   Standard Deviation: 2613.3026974498616
#
# Min:
#   Mean: 91.60734562244528
#   Mode: 54.0
#   Max: 13583.0
#   Min: 42.0
#   Standard Deviation: 139.69532424955528
#
# Max:
#   Mean: 181.96341779707967
#   Mode: 54.0
#   Max: 49014.0
#   Min: 42.0
#   Standard Deviation: 524.0308959166033
#
# AVG:
#   Mean: 124.66881523774914
#   Mode: 54.0
#   Max: 13583.0
#   Min: 42.0
#   Standard Deviation: 240.99148237709576
#
# Std:
#   Mean: 33.324806486727496
#   Mode: 0.0
#   Max: 12385.2391048564
#   Min: 0.0
#   Standard Deviation: 160.33572024742423
#
# Tot size:
#   Mean: 124.6915673484638
#   Mode: 54.0
#   Max: 13583.0
#   Min: 42.0
#   Standard Deviation: 241.54933889352685
#
# IAT:
#   Mean: 83182525.86645673
#   Mode: 3.0994415283203125e-06
#   Max: 167639436.0415293
#   Min: 0.0
#   Standard Deviation: 17047351.552197162
#
# Number:
#   Mean: 9.498489328199122
#   Mode: 9.5
#   Max: 15.0
#   Min: 1.0
#   Standard Deviation: 0.8191531728518795
#
# Magnitue:
#   Mean: 13.121819976447151
#   Mode: 10.392304845413264
#   Max: 164.8211151521552
#   Min: 9.165151389911676
#   Standard Deviation: 8.628578858997836
#
# Radius:
#   Mean: 47.094984802986566
#   Mode: 0.0
#   Max: 17551.27080917445
#   Min: 0.0
#   Standard Deviation: 226.7696446213456
#
# Covariance:
#   Mean: 30724.356527404383
#   Mode: 0.0
#   Max: 154902159.24774638
#   Min: 0.0
#   Standard Deviation: 323710.6766501625
#
# Variance:
#   Mean: 0.0964375989783293
#   Mode: 0.0
#   Max: 1.0
#   Min: 0.0
#   Standard Deviation: 0.23300099600439414
#
# Weight:
#   Mean: 141.5123696036146
#   Mode: 141.55
#   Max: 244.6
#   Min: 1.0
#   Standard Deviation: 21.068307110893688
#
# label:
#   Mean: 6.476633916569471
#   Mode: 2
#   Max: 33
#   Min: 0
#   Standard Deviation: 4.700058290089729
#
# Label Mapping:
#   DDoS-RSTFINFlood -> 0
#   DoS-TCP_Flood -> 1
#   DDoS-ICMP_Flood -> 2
#   DoS-UDP_Flood -> 3
#   DoS-SYN_Flood -> 4
#   Mirai-greeth_flood -> 5
#   DDoS-SynonymousIP_Flood -> 6
#   Mirai-udpplain -> 7
#   DDoS-SYN_Flood -> 8
#   DDoS-PSHACK_Flood -> 9
#   DDoS-TCP_Flood -> 10
#   DDoS-UDP_Flood -> 11
#   BenignTraffic -> 12
#   MITM-ArpSpoofing -> 13
#   DDoS-ACK_Fragmentation -> 14
#   Mirai-greip_flood -> 15
#   DoS-HTTP_Flood -> 16
#   DDoS-ICMP_Fragmentation -> 17
#   Recon-PortScan -> 18
#   DNS_Spoofing -> 19
#   DDoS-UDP_Fragmentation -> 20
#   Recon-OSScan -> 21
#   XSS -> 22
#   DDoS-HTTP_Flood -> 23
#   Recon-HostDiscovery -> 24
#   CommandInjection -> 25
#   VulnerabilityScan -> 26
#   DDoS-SlowLoris -> 27
#   Backdoor_Malware -> 28
#   BrowserHijacking -> 29
#   DictionaryBruteForce -> 30
#   SqlInjection -> 31
#   Recon-PingSweep -> 32
#   Uploading_Attack -> 33

# %%
#This one converts the labels from categorical to numerical and also performs the summary statistics on it.
#additonally extracts and calculates more features that are commonly used
import os
import pandas as pd

# Path to the folder containing the CSV files
folder_path = os.path.join(os.getcwd(), 'CIC')

# List of all CSV files in the folder
csv_files = [f for f in os.listdir(folder_path) if f.endswith('.csv')]
# Dictionaries to store intermediate summaries
num_chunks = {}              # Tracks the number of non-null rows processed per column
partial_sum = {}             # Accumulates the sum of values per column
partial_sum_squares = {}     # Accumulates the sum of squares of values per column (for variance)
max_values = {}              # Tracks the maximum value encountered per column
min_values = {}              # Tracks the minimum value encountered per column
value_counts = {}            # Stores frequency counts of unique values per column
label_mapping = {}           # Maps categorical labels to numerical values

#how many rows will be loaded at one time -> 500k seems to run okay with 16Gigs ram without maxing
# lower number will be slower, this seems like a good balance at least on my machine
chunksize = 500000

# Process each CSV file in the folder
for csv_file in csv_files:
    csv_path = os.path.join(folder_path, csv_file)
    print(f'Processing file: {csv_file}')
    
    # Read the CSV file in chunks
    for chunk in pd.read_csv(csv_path, chunksize=chunksize):
        # Convert categorical labels to numerical
        if 'label' in chunk.columns:
            if not label_mapping:
                unique_labels = chunk['label'].unique()
                label_mapping = {label: idx for idx, label in enumerate(unique_labels)}
            chunk['label'] = chunk['label'].map(label_mapping)

        # Feature extraction: Compute new features
        # 1. Packets per Duration
        if 'Tot sum' in chunk.columns and 'Duration' in chunk.columns:
            chunk['Packets_Duration_Ratio'] = chunk['Tot sum'] / (chunk['Duration'] + 1e-6)

        # 2. Bytes per Flow Duration
        if 'Tot sum' in chunk.columns and 'flow_dura' in chunk.columns:
            chunk['Bytes_Flow_Ratio'] = chunk['Tot sum'] / (chunk['flow_dura'] + 1e-6)

        # 3. Header Ratio
        if 'Header_Le' in chunk.columns and 'flow_dura' in chunk.columns:
            chunk['Header_Ratio'] = chunk['Header_Le'] / (chunk['flow_dura'] + 1e-6)

        # 4. TCP Flag Combinations
        if 'syn_flag_r' in chunk.columns and 'psh_flag' in chunk.columns:
            chunk['syn_psh_combo'] = chunk['syn_flag_r'] + chunk['psh_flag']

        if 'ack_flag' in chunk.columns and 'rst_flag' in chunk.columns:
            chunk['ack_rst_combo'] = chunk['ack_flag'] + chunk['rst_flag']
        
        if all(flag in chunk.columns for flag in ['fin_flag_r', 'syn_flag_r', 'rst_flag', 
                                                  'psh_flag', 'ack_flag', 'ece_flag', 'cwr_flag']):
            chunk['Total_Flags'] = (chunk['fin_flag_r'] + chunk['syn_flag_r'] + chunk['rst_flag'] +
                                    chunk['psh_flag'] + chunk['ack_flag'] + chunk['ece_flag'] + chunk['cwr_flag'])

        # 5. Active Protocol Count
        protocol_cols = ['HTTP', 'HTTPS', 'DNS', 'Telnet', 'SMTP', 'SSH', 'TCP', 'UDP']
        if all(protocol in chunk.columns for protocol in protocol_cols):
            chunk['Active_Protocol_Count'] = chunk[protocol_cols].sum(axis=1)

        # 6. Range for Stats
        if 'Max' in chunk.columns and 'Min' in chunk.columns:
            chunk['Range'] = chunk['Max'] - chunk['Min']
        
        # Continue processing to calculate summary stats as in the original code
        for col in chunk.columns:
            # Skip non-numeric columns
            if not pd.api.types.is_numeric_dtype(chunk[col]):
                continue

            # Initialize column summary trackers if not set
            if col not in partial_sum:
                partial_sum[col] = 0
                partial_sum_squares[col] = 0
                num_chunks[col] = 0
                max_values[col] = float('-inf')
                min_values[col] = float('inf')
                value_counts[col] = pd.Series(dtype=int)

            # Summarize statistics for chunk
            partial_sum[col] += chunk[col].sum()
            partial_sum_squares[col] += (chunk[col] ** 2).sum()
            num_chunks[col] += len(chunk[col].dropna())
            max_values[col] = max(max_values[col], chunk[col].max())
            min_values[col] = min(min_values[col], chunk[col].min())
            value_counts[col] = value_counts[col].add(chunk[col].value_counts(), fill_value=0)

# Calculate the statistics incrementally for each column
stats_summary = {}
print("\nCalculating statistics now")

for col in partial_sum:
    if num_chunks[col] > 0:
        # Calculate values
        mean = partial_sum[col] / num_chunks[col]
        variance = (partial_sum_squares[col] / num_chunks[col]) - (mean ** 2) if num_chunks[col] > 1 else 0
        stdev = variance ** 0.5
        mode_values = value_counts[col][value_counts[col] == value_counts[col].max()].index.tolist()
        mode = mode_values[0] if mode_values else None

        # Store calculated statistics for the current column
        stats_summary[col] = {
            'Mean': mean,
            'Mode': mode,
            'Max': max_values[col],
            'Min': min_values[col],
            'Standard Deviation': stdev,
        }

# Print the summary statistics for numeric columns
print('\nSummary Statistics Per Column')
for col, stats in stats_summary.items():
    print(f'\n{col}:')
    for stat_name, value in stats.items():
        print(f'  {stat_name}: {value}')

# Print the label mapping
print('\nLabel Mapping:')
for label, num in label_mapping.items():
    print(f'  {label} -> {num}')
# Out:
# Processing file: part-00000-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00001-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00002-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00003-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00004-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00005-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00006-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00007-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00008-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00009-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00010-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00011-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00012-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00013-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00014-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00015-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00016-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00017-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00018-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00019-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00020-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00021-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00022-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00023-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00024-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00025-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00026-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00027-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00028-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00029-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00030-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00031-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00032-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00033-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00034-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00035-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00036-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00037-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00038-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00039-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00040-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00041-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00042-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00043-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00044-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00045-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00046-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00047-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00048-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00049-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00050-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00051-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00052-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00053-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00054-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00055-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00056-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00057-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00058-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00059-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00060-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00061-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00062-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00063-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00064-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00065-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00066-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00067-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00068-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00069-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00070-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00071-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00072-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00073-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00074-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00075-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00076-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00077-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00078-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00079-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00080-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00081-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00082-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00083-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00084-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00085-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00086-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00087-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00088-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00089-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00090-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00091-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00092-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00093-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00094-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00095-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00096-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00097-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00098-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00099-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00100-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00101-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00102-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00103-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00104-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00105-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00106-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00107-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00108-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00109-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00110-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00111-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00112-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00113-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00114-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00115-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00116-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00117-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00118-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00119-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00120-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00121-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00122-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00123-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00124-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00125-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00126-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00127-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00128-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00129-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00130-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00131-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00132-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00133-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00134-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00135-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00136-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00137-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00138-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00139-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00140-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00141-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00142-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00143-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00144-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00145-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00146-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00147-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00148-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00149-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00150-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00151-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00152-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00153-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00154-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00155-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00156-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00157-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00158-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00159-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00160-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00161-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00162-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00163-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00164-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00165-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00166-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00167-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00168-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
#
# Calculating statistics now
#
# Summary Statistics Per Column
#
# flow_duration:
#   Mean: 5.765449391891019
#   Mode: 0.0
#   Max: 394357.20737375977
#   Min: 0.0
#   Standard Deviation: 285.0341682803361
#
# Header_Length:
#   Mean: 76705.96372046642
#   Mode: 54.0
#   Max: 9907147.75
#   Min: 0.0
#   Standard Deviation: 461331.74232421763
#
# Protocol Type:
#   Mean: 9.065689893437773
#   Mode: 6.0
#   Max: 47.0
#   Min: 0.0
#   Standard Deviation: 8.945532822145418
#
# Duration:
#   Mean: 66.35071687254133
#   Mode: 64.0
#   Max: 255.0
#   Min: 0.0
#   Standard Deviation: 14.019187951425424
#
# Rate:
#   Mean: 9064.057239842243
#   Mode: 0.0
#   Max: 8388608.0
#   Min: 0.0
#   Standard Deviation: 99562.48957037818
#
# Srate:
#   Mean: 9064.057239842243
#   Mode: 0.0
#   Max: 8388608.0
#   Min: 0.0
#   Standard Deviation: 99562.48957037818
#
# Drate:
#   Mean: 5.463949309321336e-06
#   Mode: 0.0
#   Max: 29.71522493800921
#   Min: 0.0
#   Standard Deviation: 0.007250765859210295
#
# fin_flag_number:
#   Mean: 0.08657207459985448
#   Mode: 0.0
#   Max: 1.0
#   Min: 0.0
#   Standard Deviation: 0.28120695314897837
#
# syn_flag_number:
#   Mean: 0.20733528151634328
#   Mode: 0.0
#   Max: 1.0
#   Min: 0.0
#   Standard Deviation: 0.4053977831154013
#
# rst_flag_number:
#   Mean: 0.09050472513738905
#   Mode: 0.0
#   Max: 1.0
#   Min: 0.0
#   Standard Deviation: 0.2869035027063886
#
# psh_flag_number:
#   Mean: 0.08775005767717528
#   Mode: 0.0
#   Max: 1.0
#   Min: 0.0
#   Standard Deviation: 0.28293106060457146
#
# ack_flag_number:
#   Mean: 0.12343168258269684
#   Mode: 0.0
#   Max: 1.0
#   Min: 0.0
#   Standard Deviation: 0.3289320633770767
#
# ece_flag_number:
#   Mean: 1.4779408017880256e-06
#   Mode: 0.0
#   Max: 1.0
#   Min: 0.0
#   Standard Deviation: 0.0012157049878482081
#
# cwr_flag_number:
#   Mean: 7.282606849390272e-07
#   Mode: 0.0
#   Max: 1.0
#   Min: 0.0
#   Standard Deviation: 0.0008533815996231708
#
# ack_count:
#   Mean: 0.09054282818385843
#   Mode: 0.0
#   Max: 7.7
#   Min: 0.0
#   Standard Deviation: 0.2864314373830106
#
# syn_count:
#   Mean: 0.3303578524966207
#   Mode: 0.0
#   Max: 12.87
#   Min: 0.0
#   Standard Deviation: 0.6635353923256606
#
# fin_count:
#   Mean: 0.09907672451840115
#   Mode: 0.0
#   Max: 248.32
#   Min: 0.0
#   Standard Deviation: 0.3271164141237784
#
# urg_count:
#   Mean: 6.2398235560157875
#   Mode: 0.0
#   Max: 4401.7
#   Min: 0.0
#   Standard Deviation: 71.8524528598533
#
# rst_count:
#   Mean: 38.468121319652525
#   Mode: 0.0
#   Max: 9613.0
#   Min: 0.0
#   Standard Deviation: 325.3846543835319
#
# HTTP:
#   Mean: 0.048234225943177375
#   Mode: 0.0
#   Max: 1.0
#   Min: 0.0
#   Standard Deviation: 0.21426078827176917
#
# HTTPS:
#   Mean: 0.05509921812861893
#   Mode: 0.0
#   Max: 1.0
#   Min: 0.0
#   Standard Deviation: 0.22817382472631212
#
# DNS:
#   Mean: 0.00013067995408273542
#   Mode: 0.0
#   Max: 1.0
#   Min: 0.0
#   Standard Deviation: 0.01143078636106617
#
# Telnet:
#   Mean: 2.1419431909971386e-08
#   Mode: 0.0
#   Max: 1.0
#   Min: 0.0
#   Standard Deviation: 0.00014635378864648267
#
# SMTP:
#   Mean: 6.425829572991416e-08
#   Mode: 0.0
#   Max: 1.0
#   Min: 0.0
#   Standard Deviation: 0.00025349219238624606
#
# SSH:
#   Mean: 4.093253437995532e-05
#   Mode: 0.0
#   Max: 1.0
#   Min: 0.0
#   Standard Deviation: 0.006397722947079261
#
# IRC:
#   Mean: 1.499360233697997e-07
#   Mode: 0.0
#   Max: 1.0
#   Min: 0.0
#   Standard Deviation: 0.00038721570330887744
#
# TCP:
#   Mean: 0.5738342704441891
#   Mode: 1.0
#   Max: 1.0
#   Min: 0.0
#   Standard Deviation: 0.49451845315212895
#
# UDP:
#   Mean: 0.21191758342370728
#   Mode: 0.0
#   Max: 1.0
#   Min: 0.0
#   Standard Deviation: 0.4086667606492646
#
# DHCP:
#   Mean: 1.713554552797711e-06
#   Mode: 0.0
#   Max: 1.0
#   Min: 0.0
#   Standard Deviation: 0.0013090269731860019
#
# ARP:
#   Mean: 6.618604460181158e-05
#   Mode: 0.0
#   Max: 1.0
#   Min: 0.0
#   Standard Deviation: 0.008135211368447137
#
# ICMP:
#   Mean: 0.1637215697470573
#   Mode: 0.0
#   Max: 1.0
#   Min: 0.0
#   Standard Deviation: 0.3700227254461768
#
# IPv:
#   Mean: 0.9998873123687216
#   Mode: 1.0
#   Max: 1.0
#   Min: 0.0
#   Standard Deviation: 0.010614844924732221
#
# LLC:
#   Mean: 0.9998873123687216
#   Mode: 1.0
#   Max: 1.0
#   Min: 0.0
#   Standard Deviation: 0.010614844924732221
#
# Tot sum:
#   Mean: 1308.3225728693212
#   Mode: 567.0
#   Max: 127335.8
#   Min: 42.0
#   Standard Deviation: 2613.3026974498616
#
# Min:
#   Mean: 91.60734562244528
#   Mode: 54.0
#   Max: 13583.0
#   Min: 42.0
#   Standard Deviation: 139.69532424955528
#
# Max:
#   Mean: 181.96341779707967
#   Mode: 54.0
#   Max: 49014.0
#   Min: 42.0
#   Standard Deviation: 524.0308959166033
#
# AVG:
#   Mean: 124.66881523774914
#   Mode: 54.0
#   Max: 13583.0
#   Min: 42.0
#   Standard Deviation: 240.99148237709576
#
# Std:
#   Mean: 33.324806486727496
#   Mode: 0.0
#   Max: 12385.2391048564
#   Min: 0.0
#   Standard Deviation: 160.33572024742423
#
# Tot size:
#   Mean: 124.6915673484638
#   Mode: 54.0
#   Max: 13583.0
#   Min: 42.0
#   Standard Deviation: 241.54933889352685
#
# IAT:
#   Mean: 83182525.86645673
#   Mode: 3.0994415283203125e-06
#   Max: 167639436.0415293
#   Min: 0.0
#   Standard Deviation: 17047351.552197162
#
# Number:
#   Mean: 9.498489328199122
#   Mode: 9.5
#   Max: 15.0
#   Min: 1.0
#   Standard Deviation: 0.8191531728518795
#
# Magnitue:
#   Mean: 13.121819976447151
#   Mode: 10.392304845413264
#   Max: 164.8211151521552
#   Min: 9.165151389911676
#   Standard Deviation: 8.628578858997836
#
# Radius:
#   Mean: 47.094984802986566
#   Mode: 0.0
#   Max: 17551.27080917445
#   Min: 0.0
#   Standard Deviation: 226.7696446213456
#
# Covariance:
#   Mean: 30724.356527404383
#   Mode: 0.0
#   Max: 154902159.24774638
#   Min: 0.0
#   Standard Deviation: 323710.6766501625
#
# Variance:
#   Mean: 0.0964375989783293
#   Mode: 0.0
#   Max: 1.0
#   Min: 0.0
#   Standard Deviation: 0.23300099600439414
#
# Weight:
#   Mean: 141.5123696036146
#   Mode: 141.55
#   Max: 244.6
#   Min: 1.0
#   Standard Deviation: 21.068307110893688
#
# label:
#   Mean: 6.476633916569471
#   Mode: 2
#   Max: 33
#   Min: 0
#   Standard Deviation: 4.700058290089729
#
# Packets_Duration_Ratio:
#   Mean: 6031.330035137079
#   Mode: 8.859374861572269
#   Max: 6842800000.000001
#   Min: 0.27731092320457595
#   Standard Deviation: 2518963.8887677714
#
# Active_Protocol_Count:
#   Mean: 0.889256996105883
#   Mode: 1.0
#   Max: 2.0
#   Min: 0.0
#   Standard Deviation: 0.5527108425375766
#
# Range:
#   Mean: 90.35607217463439
#   Mode: 0.0
#   Max: 48948.0
#   Min: 0.0
#   Standard Deviation: 475.4857463163653
#
# Label Mapping:
#   DDoS-RSTFINFlood -> 0
#   DoS-TCP_Flood -> 1
#   DDoS-ICMP_Flood -> 2
#   DoS-UDP_Flood -> 3
#   DoS-SYN_Flood -> 4
#   Mirai-greeth_flood -> 5
#   DDoS-SynonymousIP_Flood -> 6
#   Mirai-udpplain -> 7
#   DDoS-SYN_Flood -> 8
#   DDoS-PSHACK_Flood -> 9
#   DDoS-TCP_Flood -> 10
#   DDoS-UDP_Flood -> 11
#   BenignTraffic -> 12
#   MITM-ArpSpoofing -> 13
#   DDoS-ACK_Fragmentation -> 14
#   Mirai-greip_flood -> 15
#   DoS-HTTP_Flood -> 16
#   DDoS-ICMP_Fragmentation -> 17
#   Recon-PortScan -> 18
#   DNS_Spoofing -> 19
#   DDoS-UDP_Fragmentation -> 20
#   Recon-OSScan -> 21
#   XSS -> 22
#   DDoS-HTTP_Flood -> 23
#   Recon-HostDiscovery -> 24
#   CommandInjection -> 25
#   VulnerabilityScan -> 26
#   DDoS-SlowLoris -> 27
#   Backdoor_Malware -> 28
#   BrowserHijacking -> 29
#   DictionaryBruteForce -> 30
#   SqlInjection -> 31
#   Recon-PingSweep -> 32
#   Uploading_Attack -> 33

# %%
#This one converts the labels from categorical to numerical and also performs the summary statistics on it.
#additonally extracts and calculates more features that are commonly used
# as well as printing everthing to a csv file.
import os
import pandas as pd

# Path to the folder containing the CSV files
folder_path = os.path.join(os.getcwd(), 'CIC')

# List of all CSV files in the folder
csv_files = [f for f in os.listdir(folder_path) if f.endswith('.csv')]

# Dictionaries to store intermediate summaries
num_chunks = {}              # Tracks the number of non-null rows processed per column
partial_sum = {}             # Accumulates the sum of values per column
partial_sum_squares = {}     # Accumulates the sum of squares of values per column (for variance)
max_values = {}              # Tracks the maximum value encountered per column
min_values = {}              # Tracks the minimum value encountered per column
value_counts = {}            # Stores frequency counts of unique values per column
label_mapping = {}           # Maps categorical labels to numerical values

# How many rows will be loaded at one time -> 500k seems to run okay with 16GB RAM without maxing
chunksize = 500000

# Process each CSV file in the folder
for csv_file in csv_files:
    csv_path = os.path.join(folder_path, csv_file)
    print(f'Processing file: {csv_file}')
    
    # Read the CSV file in chunks
    for chunk in pd.read_csv(csv_path, chunksize=chunksize):
        # Convert categorical labels to numerical
        if 'label' in chunk.columns:
            if not label_mapping:
                unique_labels = chunk['label'].unique()
                label_mapping = {label: idx for idx, label in enumerate(unique_labels)}
            chunk['label'] = chunk['label'].map(label_mapping)

        # Feature extraction: Compute new features
        # 1. Packets per Duration
        if 'Tot sum' in chunk.columns and 'Duration' in chunk.columns:
            chunk['Packets_Duration_Ratio'] = chunk['Tot sum'] / (chunk['Duration'] + 1e-6)

        # 2. Bytes per Flow Duration
        if 'Tot sum' in chunk.columns and 'flow_dura' in chunk.columns:
            chunk['Bytes_Flow_Ratio'] = chunk['Tot sum'] / (chunk['flow_dura'] + 1e-6)

        # 3. Header Ratio
        if 'Header_Le' in chunk.columns and 'flow_dura' in chunk.columns:
            chunk['Header_Ratio'] = chunk['Header_Le'] / (chunk['flow_dura'] + 1e-6)

        # 4. TCP Flag Combinations
        if 'syn_flag_r' in chunk.columns and 'psh_flag' in chunk.columns:
            chunk['syn_psh_combo'] = chunk['syn_flag_r'] + chunk['psh_flag']

        if 'ack_flag' in chunk.columns and 'rst_flag' in chunk.columns:
            chunk['ack_rst_combo'] = chunk['ack_flag'] + chunk['rst_flag']
        
        if all(flag in chunk.columns for flag in ['fin_flag_r', 'syn_flag_r', 'rst_flag', 
                                                  'psh_flag', 'ack_flag', 'ece_flag', 'cwr_flag']):
            chunk['Total_Flags'] = (chunk['fin_flag_r'] + chunk['syn_flag_r'] + chunk['rst_flag'] +
                                    chunk['psh_flag'] + chunk['ack_flag'] + chunk['ece_flag'] + chunk['cwr_flag'])

        # 5. Active Protocol Count
        protocol_cols = ['HTTP', 'HTTPS', 'DNS', 'Telnet', 'SMTP', 'SSH', 'TCP', 'UDP']
        if all(protocol in chunk.columns for protocol in protocol_cols):
            chunk['Active_Protocol_Count'] = chunk[protocol_cols].sum(axis=1)

        # 6. Range for Stats
        if 'Max' in chunk.columns and 'Min' in chunk.columns:
            chunk['Range'] = chunk['Max'] - chunk['Min']
        
        # Continue processing to calculate summary stats as in the original code
        for col in chunk.columns:
            # Skip non-numeric columns
            if not pd.api.types.is_numeric_dtype(chunk[col]):
                continue

            # Initialize column summary trackers if not set
            if col not in partial_sum:
                partial_sum[col] = 0
                partial_sum_squares[col] = 0
                num_chunks[col] = 0
                max_values[col] = float('-inf')
                min_values[col] = float('inf')
                value_counts[col] = pd.Series(dtype=int)

            # Summarize statistics for chunk
            partial_sum[col] += chunk[col].sum()
            partial_sum_squares[col] += (chunk[col] ** 2).sum()
            num_chunks[col] += len(chunk[col].dropna())
            max_values[col] = max(max_values[col], chunk[col].max())
            min_values[col] = min(min_values[col], chunk[col].min())
            value_counts[col] = value_counts[col].add(chunk[col].value_counts(), fill_value=0)

# Calculate the statistics incrementally for each column
stats_summary = {}
print("\nCalculating statistics now")

for col in partial_sum:
    if num_chunks[col] > 0:
        # Calculate summary statistics
        mean = partial_sum[col] / num_chunks[col]
        variance = (partial_sum_squares[col] / num_chunks[col]) - (mean ** 2) if num_chunks[col] > 1 else 0
        stdev = variance ** 0.5
        mode_values = value_counts[col][value_counts[col] == value_counts[col].max()].index.tolist()
        mode = mode_values[0] if mode_values else None

        # Store calculated statistics for the current column
        stats_summary[col] = {
            'Metric': 'Summary',
            'Mean': mean,
            'Mode': mode,
            'Max': max_values[col],
            'Min': min_values[col],
            'Standard Deviation': stdev,
        }

# Combine everything into a single DataFrame
print('\nCombining summary statistics and label mapping into a single CSV...')

# Process the summary statistics
summary_df = pd.DataFrame.from_dict(stats_summary, orient='index').reset_index()
summary_df.rename(columns={'index': 'Feature'}, inplace=True)
summary_df['Group'] = 'Summary'  # Add a group identifier

# Process the label mapping
label_mapping_df = pd.DataFrame(list(label_mapping.items()), columns=['Label', 'Mapped_Value'])
label_mapping_df['Metric'] = 'Label Mapping'
label_mapping_df['Feature'] = 'label'
label_mapping_df['Group'] = 'Mapping'

# Match label mapping columns to summary columns
for col in ['Mean', 'Mode', 'Max', 'Min', 'Standard Deviation']:
    label_mapping_df[col] = None

# Combine the two tables
combined_df = pd.concat([summary_df, label_mapping_df], ignore_index=True)

# Save the combined CSV
output_path = os.path.join(os.getcwd(), 'output_combined.csv')
combined_df.to_csv(output_path, index=False)

print(f"\nCombined output saved to: {output_path}")
print("Done!")
# Out:
# Processing file: part-00000-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00001-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00002-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00003-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00004-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00005-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00006-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00007-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00008-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00009-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00010-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00011-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00012-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00013-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00014-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00015-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00016-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00017-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00018-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00019-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00020-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00021-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00022-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00023-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00024-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00025-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00026-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00027-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00028-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00029-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00030-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00031-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00032-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00033-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00034-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00035-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00036-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00037-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00038-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00039-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00040-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00041-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00042-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00043-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00044-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00045-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00046-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00047-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00048-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00049-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00050-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00051-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00052-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00053-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00054-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00055-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00056-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00057-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00058-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00059-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00060-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00061-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00062-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00063-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00064-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00065-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00066-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00067-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00068-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00069-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00070-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00071-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00072-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00073-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00074-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00075-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00076-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00077-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00078-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00079-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00080-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00081-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00082-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00083-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00084-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00085-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00086-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00087-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00088-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00089-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00090-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00091-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00092-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00093-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00094-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00095-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00096-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00097-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00098-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00099-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00100-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00101-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00102-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00103-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00104-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00105-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00106-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00107-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00108-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00109-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00110-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00111-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00112-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00113-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00114-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00115-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00116-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00117-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00118-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00119-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00120-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00121-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00122-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00123-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00124-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00125-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00126-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00127-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00128-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00129-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00130-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00131-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00132-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00133-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00134-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00135-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00136-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00137-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00138-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00139-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00140-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00141-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00142-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00143-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00144-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00145-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00146-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00147-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00148-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00149-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00150-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00151-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00152-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00153-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00154-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00155-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00156-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00157-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00158-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00159-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00160-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00161-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00162-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00163-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00164-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00165-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00166-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00167-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Processing file: part-00168-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
#
# Calculating statistics now
#
# Combining summary statistics and label mapping into a single CSV...
#
# Combined output saved to: C:\Users\vlad.serban\Home\CIC analysis\output_combined.csv
# Done!
# C:\Users\vlad.serban\AppData\Local\Temp\ipykernel_2412\3112021312.py:135: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   combined_df = pd.concat([summary_df, label_mapping_df], ignore_index=True)
